# %%
"""
Kafka 컨슈머를 활용하여 특정 키 값을 가진 메시지가 동일한 파티션에서 소비되는지 확인하는 실습입니다.

TODO:
1. kafka-python 라이브러리를 사용하여 KafkaConsumer를 생성합니다.
2. test-topic을 구독하고, 메시지를 소비합니다.
3. 메시지가 들어온 파티션 정보를 확인하여 동일한 키가 동일한 파티션으로 들어가는지 검증합니다.
"""

from kafka import KafkaConsumer

# %%
# TODO 1: KafkaConsumer를 생성하세요.
consumer = KafkaConsumer(
    "test-topic",
    bootstrap_servers="localhost:9092",  # Kafka 브로커 주소 설정
    auto_offset_reset="earliest",  # 오프셋 초기화 방식 설정
    enable_auto_commit=True,  # 자동 오프셋 커밋 여부 설정
    group_id="partition-consumer"  # 컨슈머 그룹 ID 설정
)

# %%
# TODO 2: 메시지를 지속적으로 소비하고, 들어온 파티션 정보를 출력하세요.
for message in consumer:  # 메시지를 소비하는 컨슈머 객체
    print(f"Received: {message.value.decode('utf-8')}, Key: {message.key.decode('utf-8')}, Partition: {message.partition}")
# Out:
# Received: message-2, Key: key3, Partition: 1
# Received: message-5, Key: key3, Partition: 1
# Received: message-8, Key: key3, Partition: 1
# Received: message-0, Key: key1, Partition: 2
# Received: message-1, Key: key2, Partition: 2
# Received: message-3, Key: key1, Partition: 2
# Received: message-4, Key: key2, Partition: 2
# Received: message-6, Key: key1, Partition: 2
# Received: message-7, Key: key2, Partition: 2
# Received: message-9, Key: key1, Partition: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # TODO 2: 메시지를 지속적으로 소비하고, 들어온 파티션 정보를 출력하세요.
# ----> 2 for message in consumer:  # 메시지를 소비하는 컨슈머 객체
#       3     print(f"Received: {message.value.decode('utf-8')}, Key: {message.key.decode('utf-8')}, Partition: {message.partition}")
#
# File ~/data_env/lib/python3.10/site-packages/kafka/consumer/group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File ~/data_env/lib/python3.10/site-packages/kafka/consumer/group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File ~/data_env/lib/python3.10/site-packages/kafka/consumer/group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File ~/data_env/lib/python3.10/site-packages/kafka/consumer/group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File ~/data_env/lib/python3.10/site-packages/kafka/consumer/group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File ~/data_env/lib/python3.10/site-packages/kafka/client_async.py:614, in KafkaClient.poll(self, timeout_ms, future)
#     607         timeout = min(
#     608             timeout_ms,
#     609             metadata_timeout_ms,
#     610             idle_connection_timeout_ms,
#     611             request_timeout_ms)
#     612         timeout = max(0, timeout)  # avoid negative timeouts
# --> 614     self._poll(timeout / 1000)
#     616 # called without the lock to avoid deadlock potential
#     617 # if handlers need to acquire locks
#     618 responses.extend(self._fire_pending_completed_requests())
#
# File ~/data_env/lib/python3.10/site-packages/kafka/client_async.py:648, in KafkaClient._poll(self, timeout)
#     645 self._register_send_sockets()
#     647 start_select = time.time()
# --> 648 ready = self._selector.select(timeout)
#     649 end_select = time.time()
#     650 if self._sensors:
#
# File /usr/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
